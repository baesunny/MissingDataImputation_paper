# %%
import pandas as pd
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# 예제 데이터 생성
data = pd.DataFrame({
    'age': [25, np.nan, 28, 35, np.nan],
    'income': [50000, 60000, np.nan, 80000, 70000],
    'education_years': [12, 16, 14, np.nan, 13]
})

# MICE 방식으로 결측치 대체
imputer = IterativeImputer(random_state=0)
imputed_data = imputer.fit_transform(data)

# 데이터프레임으로 변환
imputed_df = pd.DataFrame(imputed_data, columns=data.columns)

# %%
data
# Out:
#     age   income  education_years
# 0  25.0  50000.0             12.0
# 1   NaN  60000.0             16.0
# 2  28.0      NaN             14.0
# 3  35.0  80000.0              NaN
# 4   NaN  70000.0             13.0

# %%
imputed_df
# Out:
#          age       income  education_years
# 0  25.000000  50000.00000        12.000000
# 1  27.668995  60000.00000        16.000000
# 2  28.000000  64999.99643        14.000000
# 3  35.000000  80000.00000        14.708388
# 4  30.997670  70000.00000        13.000000
